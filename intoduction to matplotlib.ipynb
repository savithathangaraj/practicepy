# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([1,2,3],[4,5,6]);

# %%
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot([1,2,3],[4,5,6])
plt.show()

# %%
fig,ax=plt.subplots()
x=[1,2,3,4]
y=[100,250,300,400]
ax.plot(x,y);

# %% [markdown]
# # anatomy of matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(10,10))
ax.plot(x,y)
ax.set(title="simple_plot",xlabel="x-axis",ylabel="y-axis")
fig.savefig("sample_plot.png")

# %% [markdown]
# # scatter plot and bar plot

# %%
import numpy as np
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x));

# %%
nut_butter_prices={"almond butter":10,"peanut butter":8,"cashew butter":12}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),height=nut_butter_prices.values())
ax.set(title="dan's nut butter",ylabel="price($)");

# %% [markdown]
# # histograms and subplots

# %%
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
x=np.random.randn(1000)
fig,ax=plt.subplots()
ax.hist(x);

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# ## subplot2

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.rand(1000));

# %% [markdown]
# ## plotting of pandas

# %%
import pandas as pd
car=pd.read_csv("car-sales.csv")
car
car["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
ts=pd.Series(np.random.randn(1000))
index=pd.date_range("1/1/2020",periods=(1000))
ts=ts.cumsum()
ts.plot();

# %% [markdown]
# # plotting from pandas2

# %%
type(car["Price"])
# Out:
# pandas.core.series.Series

# %%
car
type(car["Price"])
# Out:
# pandas.core.series.Series

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car["Price"]=car["Price"].astype(str)

# %%
car["Price"]=car["Price"].str.replace('[\$\,\.]','')
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car["total sales"]=car["Price"].astype(int).cumsum()
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  total sales
# 0  Toyota  White         150043      4   400000       400000
# 1   Honda    Red          87899      4   500000       900000
# 2  Toyota   Blue          32549      3   700000      1600000
# 3     BMW  Black          11179      5  2200000      3800000
# 4  Nissan  White         213095      4   350000      4150000
# 5  Toyota  Green          99213      4   450000      4600000
# 6   Honda   Blue          45698      4   750000      5350000
# 7   Honda   Blue          54738      4   700000      6050000
# 8  Toyota  White          60000      4   625000      6675000
# 9  Nissan  White          31600      4   970000      7645000

# %%
car["sale data"]=pd.date_range('14/6/2020',periods=len(car));
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  total sales  sale data
# 0  Toyota  White         150043      4   400000       400000 2020-06-14
# 1   Honda    Red          87899      4   500000       900000 2020-06-15
# 2  Toyota   Blue          32549      3   700000      1600000 2020-06-16
# 3     BMW  Black          11179      5  2200000      3800000 2020-06-17
# 4  Nissan  White         213095      4   350000      4150000 2020-06-18
# 5  Toyota  Green          99213      4   450000      4600000 2020-06-19
# 6   Honda   Blue          45698      4   750000      5350000 2020-06-20
# 7   Honda   Blue          54738      4   700000      6050000 2020-06-21
# 8  Toyota  White          60000      4   625000      6675000 2020-06-22
# 9  Nissan  White          31600      4   970000      7645000 2020-06-23

# %%
car.plot(x="sale data",y="total sales");

# %%
car["Price"]=car["Price"].astype(int)
car["Price"].dtype
# Out:
# dtype('int32')

# %%
car.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %% [markdown]
# # part3

# %%
import numpy as np
x=np.random.rand(10,4)
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.448976  0.815088  0.721806  0.345638
# 1  0.448033  0.239974  0.116325  0.823645
# 2  0.919334  0.692542  0.701430  0.900457
# 3  0.526110  0.516069  0.257190  0.337338
# 4  0.542387  0.022450  0.523296  0.108148
# 5  0.107004  0.590914  0.060630  0.056093
# 6  0.077399  0.561318  0.963203  0.910474
# 7  0.826530  0.292135  0.886143  0.732868
# 8  0.401584  0.208367  0.664859  0.043506
# 9  0.264722  0.197735  0.508667  0.851773

# %%
df.plot.bar(figsize=(13,6));

# %%
df.plot(kind="bar",figsize=(13,6));

# %%
car.plot(x="Make",y="Odometer (KM)",kind="pie",figsize=(18,6));

# %%
car["Odometer (KM)"].plot.hist(bins=10);

# %%
car["Odometer (KM)"].plot(kind="hist");

# %% [markdown]
# # part4

# %%
import pandas as pd
heart=pd.read_csv("heart-diseases.csv");
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart["age"].plot.hist();

# %%
heart.plot.hist(subplots=True,figsize=(15,30));

# %% [markdown]
# # part 5

# %%
#oo plots
over50=heart[heart["age"]>50]
over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
#pyplot method
over50.plot(x='age',y='chol',kind='scatter',figsize=(15,8),c='target');

# %%
#oo method
# %matplotlib inline
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(10,6))
over50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax)
#ax.set_xlim([45,100]);

# %% [markdown]
# # part 6

# %%
fig,ax=plt.subplots(figsize=(15,6))
scatter=ax.scatter(x=over50["age"],y=over50["chol"],c=over50["target"]);
ax.set(title="Heart Disease and cholestrol analysis",xlabel="Age",ylabel="cholestrol")
ax.legend(*scatter.legend_elements(),title="target")
ax.axhline(over50["chol"].mean(),linestyle='--');

# %% [markdown]
# # part 7

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over50["age"],y=over50["chol"],c=over50["target"])
ax0.set(title="Heart diseases and cholestrol analysis",xlabel="Age",ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over50["chol"].mean(),linestyle="-.")
scatter=ax1.scatter(x=over50["age"],y=over50["thalach"],c=over50["target"])
ax1.set(title="Heart disease and thalach analysis",xlabel="Age",ylabel="thalach")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over50["thalach"].mean(),linestyle="-.")


fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# # customizing your plots

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('seaborn-dark-palette')
car["Price"].plot(figsize=(13,6));

# %%
car.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
import numpy as np
x=np.random.rand(10,4)
df=pd.DataFrame(x,columns=['a','b','c','d'])
df.plot(kind="bar");

# %%
ax=df.plot(kind="bar")
ax.set(title="Random Number Bar",xlabel="ROW",ylabel="RANDOM")
ax.legend().set_visible(True);

# %% [markdown]
# # plots 2

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over50["age"],y=over50["chol"],c=over50["target"],cmap="summer")
ax0.set(title="Heart diseases and cholestrol analysis",xlabel="Age",ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over50["chol"].mean(),linestyle="-.")
scatter=ax1.scatter(x=over50["age"],y=over50["thalach"],c=over50["target"],cmap="summer")
ax1.set(title="Heart disease and thalach analysis",xlabel="Age",ylabel="thalach")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over50["thalach"].mean(),linestyle="-.")


fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# # saving and sharing

# %%
fig.savefig("dualplot.png")
